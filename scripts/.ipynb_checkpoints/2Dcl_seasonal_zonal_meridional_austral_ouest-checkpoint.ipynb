# %%
import netCDF4
import matplotlib.pyplot as plt
import numpy as np

# %%
# OBS
path = '/home/jcharrel/Documents/stage_M2/data/CALIPSO/'
ncfile_obs=path+"CALIPSO_2Dcl_seasonal_averaged_concatenated_2008_2022_r144x90.nc"
nc_obs = netCDF4.Dataset(ncfile_obs)

# %%
# MASK
path = '/home/jcharrel/Documents/stage_M2/data/LMDZ6A/'
ncfile_mask=path+"LmdzOr6Actrl_SE_1980_1999_1M_histmth_phis_r144x90.nc"
nc_mask = netCDF4.Dataset(ncfile_mask)

# %%
# LMDZ6A
path = '/home/jcharrel/Documents/stage_M2/data/LMDZ6A/'
ncfile_lmdz6a=path+'LmdzOr6Actrl_calipso_r144x90.nc'
nc_lmdz6a = netCDF4.Dataset(ncfile_lmdz6a)

# %%
# GRID
lon = nc_obs.variables['lon'][:]
lat = nc_obs.variables['lat'][:]

lat_austral = lat[lat <= -30]
lat_id_austral = lat <= -30

lon[lon > 180] -= 360
lon_id = np.argsort(lon)
lon = lon[lon_id]

lon_ouest = lon[lon<=0]
lon_id_ouest = lon <= 0

import matplotlib.path as mpath
theta = np.linspace(0, 2*np.pi, 100)
map_circle = mpath.Path(np.vstack([np.sin(theta), np.cos(theta)]).T * 0.5 + [0.5, 0.5])

# %%
# GEOPOTENTIAL FOR MASK
g = 9.81 # m/s
alt_austral = nc_mask.variables['phis'][:,lat_id_austral,lon_id]/g #m
alt_austral = alt_austral[:,:,lon_id_ouest]

# %%
# MASK
mask_antarctica = np.where(alt_austral > 0.1, 1, np.nan) #pour masquer la partie antarctique

# %%
# VARIABLES - OBS
cllobs_austral = nc_obs.variables['cllcalipso'][:,lat_id_austral,lon_id]
clmobs_austral = nc_obs.variables['clmcalipso'][:,lat_id_austral,lon_id]
clhobs_austral = nc_obs.variables['clhcalipso'][:,lat_id_austral,lon_id]
cltobs_austral = nc_obs.variables['cltcalipso'][:,lat_id_austral,lon_id]

# VARIABLE - LMDZ6A
clllmdz6a_austral = nc_lmdz6a.variables['cllcalipso'][:,lat_id_austral,lon_id]
clmlmdz6a_austral = nc_lmdz6a.variables['clmcalipso'][:,lat_id_austral,lon_id]
clhlmdz6a_austral = nc_lmdz6a.variables['clhcalipso'][:,lat_id_austral,lon_id]
cltlmdz6a_austral = nc_lmdz6a.variables['cltcalipso'][:,lat_id_austral,lon_id]

# %%
#SELECT ONLY WEST

# OBS
cllobs_austral = cllobs_austral[:,:,lon_id_ouest]
clmobs_austral = clmobs_austral[:,:,lon_id_ouest]
clhobs_austral = clhobs_austral[:,:,lon_id_ouest]
cltobs_austral = cltobs_austral[:,:,lon_id_ouest]

# LMDZ6A
clllmdz6a_austral = clllmdz6a_austral[:,:,lon_id_ouest]
clmlmdz6a_austral = clmlmdz6a_austral[:,:,lon_id_ouest]
clhlmdz6a_austral = clhlmdz6a_austral[:,:,lon_id_ouest]
cltlmdz6a_austral = cltlmdz6a_austral[:,:,lon_id_ouest]

# %%
# MASK LMDZ6A WHERE THERE IS NO OBS DATA
mask_lat_obs_cll = np.where(cllobs_austral.mask == True, 1, np.nan)
mask_lat_obs_clm = np.where(clmobs_austral.mask == True, 1, np.nan)
mask_lat_obs_clh = np.where(clhobs_austral.mask == True, 1, np.nan)
mask_lat_obs_clt = np.where(cltobs_austral.mask == True, 1, np.nan)

clllmdz6a_austral = np.ma.masked_where(mask_lat_obs_cll >=0, clllmdz6a_austral)
clmlmdz6a_austral = np.ma.masked_where(mask_lat_obs_clm >=0, clmlmdz6a_austral)
clhlmdz6a_austral = np.ma.masked_where(mask_lat_obs_clh >=0, clhlmdz6a_austral)
cltlmdz6a_austral = np.ma.masked_where(mask_lat_obs_clt >=0, cltlmdz6a_austral)

# %%
# MASK ANTARCTICA FOR OBS
cllobs_austral = np.ma.masked_where(mask_antarctica >=0, cllobs_austral)
clmobs_austral = np.ma.masked_where(mask_antarctica >=0, clmobs_austral)
clhobs_austral = np.ma.masked_where(mask_antarctica >=0, clhobs_austral)
cltobs_austral = np.ma.masked_where(mask_antarctica >=0, cltobs_austral)

# MASK ANTARCTICA FOR LMDZ6A
clllmdz6a_austral = np.ma.masked_where(mask_antarctica >=0, clllmdz6a_austral)
clmlmdz6a_austral = np.ma.masked_where(mask_antarctica >=0, clmlmdz6a_austral)
clhlmdz6a_austral = np.ma.masked_where(mask_antarctica >=0, clhlmdz6a_austral)
cltlmdz6a_austral = np.ma.masked_where(mask_antarctica >=0, cltlmdz6a_austral)

# %%
# SELECT SEASONS AND MEAN 

# OBS
cllobs_DJF = np.mean(np.mean(cllobs_austral, axis=2)[[0,1,11],:], axis=0)
cllobs_MAM = np.mean(np.mean(cllobs_austral, axis=2)[[2,3,4],:], axis=0)
cllobs_JJA = np.mean(np.mean(cllobs_austral, axis=2)[[5,6,7],:], axis=0)
cllobs_SON = np.mean(np.mean(cllobs_austral, axis=2)[[8,9,10],:], axis=0)
cllobs_seasons = np.ma.dstack((cllobs_DJF, cllobs_MAM, cllobs_JJA, cllobs_SON))
cllobs_mean = np.mean(cllobs_seasons, axis=(0,2))

clmobs_DJF = np.mean(np.mean(clmobs_austral, axis=2)[[0,1,11],:], axis=0)
clmobs_MAM = np.mean(np.mean(clmobs_austral, axis=2)[[2,3,4],:], axis=0)
clmobs_JJA = np.mean(np.mean(clmobs_austral, axis=2)[[5,6,7],:], axis=0)
clmobs_SON = np.mean(np.mean(clmobs_austral, axis=2)[[8,9,10],:], axis=0)
clmobs_seasons = np.ma.dstack((clmobs_DJF, clmobs_MAM, clmobs_JJA, clmobs_SON))
clmobs_mean = np.mean(clmobs_seasons, axis=(0,2))

clhobs_DJF = np.mean(np.mean(clhobs_austral, axis=2)[[0,1,11],:], axis=0)
clhobs_MAM = np.mean(np.mean(clhobs_austral, axis=2)[[2,3,4],:], axis=0)
clhobs_JJA = np.mean(np.mean(clhobs_austral, axis=2)[[5,6,7],:], axis=0)
clhobs_SON = np.mean(np.mean(clhobs_austral, axis=2)[[8,9,10],:], axis=0)
clhobs_seasons = np.ma.dstack((clhobs_DJF, clhobs_MAM, clhobs_JJA, clhobs_SON))
clhobs_mean = np.mean(clhobs_seasons, axis=(0,2))

cltobs_DJF = np.mean(np.mean(cltobs_austral, axis=2)[[0,1,11],:], axis=0)
cltobs_MAM = np.mean(np.mean(cltobs_austral, axis=2)[[2,3,4],:], axis=0)
cltobs_JJA = np.mean(np.mean(cltobs_austral, axis=2)[[5,6,7],:], axis=0)
cltobs_SON = np.mean(np.mean(cltobs_austral, axis=2)[[8,9,10],:], axis=0)
cltobs_seasons = np.ma.dstack((cltobs_DJF, cltobs_MAM, cltobs_JJA, cltobs_SON))
cltobs_mean = np.mean(cltobs_seasons, axis=(0,2))

# LMDZ6A
clllmdz6a_DJF = np.mean(np.mean(clllmdz6a_austral, axis=2)[[0,1,11],:], axis=0)
clllmdz6a_MAM = np.mean(np.mean(clllmdz6a_austral, axis=2)[[2,3,4],:], axis=0)
clllmdz6a_JJA = np.mean(np.mean(clllmdz6a_austral, axis=2)[[5,6,7],:], axis=0)
clllmdz6a_SON = np.mean(np.mean(clllmdz6a_austral, axis=2)[[8,9,10],:], axis=0)
clllmdz6a_seasons = np.ma.dstack((clllmdz6a_DJF, clllmdz6a_MAM, clllmdz6a_JJA, clllmdz6a_SON))
clllmdz6a_mean = np.mean(clllmdz6a_seasons, axis=(0,2))

clmlmdz6a_DJF = np.mean(np.mean(clmlmdz6a_austral, axis=2)[[0,1,11],:], axis=0)
clmlmdz6a_MAM = np.mean(np.mean(clmlmdz6a_austral, axis=2)[[2,3,4],:], axis=0)
clmlmdz6a_JJA = np.mean(np.mean(clmlmdz6a_austral, axis=2)[[5,6,7],:], axis=0)
clmlmdz6a_SON = np.mean(np.mean(clmlmdz6a_austral, axis=2)[[8,9,10],:], axis=0)
clmlmdz6a_seasons = np.ma.dstack((clmlmdz6a_DJF, clmlmdz6a_MAM, clmlmdz6a_JJA, clmlmdz6a_SON))
clmlmdz6a_mean = np.mean(clmlmdz6a_seasons, axis=(0,2))

clhlmdz6a_DJF = np.mean(np.mean(clhlmdz6a_austral, axis=2)[[0,1,11],:], axis=0)
clhlmdz6a_MAM = np.mean(np.mean(clhlmdz6a_austral, axis=2)[[2,3,4],:], axis=0)
clhlmdz6a_JJA = np.mean(np.mean(clhlmdz6a_austral, axis=2)[[5,6,7],:], axis=0)
clhlmdz6a_SON = np.mean(np.mean(clhlmdz6a_austral, axis=2)[[8,9,10],:], axis=0)
clhlmdz6a_seasons = np.ma.dstack((clhlmdz6a_DJF, clhlmdz6a_MAM, clhlmdz6a_JJA, clhlmdz6a_SON))
clhlmdz6a_mean = np.mean(clhlmdz6a_seasons, axis=(0,2))

cltlmdz6a_DJF = np.mean(np.mean(cltlmdz6a_austral, axis=2)[[0,1,11],:], axis=0)
cltlmdz6a_MAM = np.mean(np.mean(cltlmdz6a_austral, axis=2)[[2,3,4],:], axis=0)
cltlmdz6a_JJA = np.mean(np.mean(cltlmdz6a_austral, axis=2)[[5,6,7],:], axis=0)
cltlmdz6a_SON = np.mean(np.mean(cltlmdz6a_austral, axis=2)[[8,9,10],:], axis=0)
cltlmdz6a_seasons = np.ma.dstack((cltlmdz6a_DJF, cltlmdz6a_MAM, cltlmdz6a_JJA, cltlmdz6a_SON))
cltlmdz6a_mean = np.mean(cltlmdz6a_seasons, axis=(0,2))

# %%
fig, axes = plt.subplots(figsize=(16,9), nrows=2, ncols=2)
pltcounter = 0
for plotid in axes.flat:
    pltcounter = pltcounter + 1
    if pltcounter == 1:
        plotid.set_title("a) Low", size=15)
        plotid.set_ylabel('Cloud cover')
        plotid.plot(lat_austral,cllobs_seasons[0,:,0], c='r')
        plotid.plot(lat_austral,cllobs_seasons[0,:,1], c='orange')
        plotid.plot(lat_austral,cllobs_seasons[0,:,2], c='b')
        plotid.plot(lat_austral,cllobs_seasons[0,:,3], c='g')
        plotid.plot(lat_austral, cllobs_mean, c='k')
        plotid.plot(lat_austral,clllmdz6a_seasons[0,:,0], ':', c='r')
        plotid.plot(lat_austral,clllmdz6a_seasons[0,:,1], ':', c='orange')
        plotid.plot(lat_austral,clllmdz6a_seasons[0,:,2], ':', c='b')
        plotid.plot(lat_austral,clllmdz6a_seasons[0,:,3], ':', c='g')
        plotid.plot(lat_austral, clllmdz6a_mean, ':', c='k')
        plotid.set_xticks(np.arange(-85,-25,5))
        plotid.set_ylim(0,0.8)
        
    elif pltcounter == 2:
        plotid.set_title("b) Mid", size=15)
        plotid.plot(lat_austral,clmobs_seasons[0,:,0], c='r')
        plotid.plot(lat_austral,clmobs_seasons[0,:,1], c='orange')
        plotid.plot(lat_austral,clmobs_seasons[0,:,2], c='b')
        plotid.plot(lat_austral,clmobs_seasons[0,:,3], c='g')
        plotid.plot(lat_austral, clmobs_mean, c='k')
        plotid.plot(lat_austral,clmlmdz6a_seasons[0,:,0], ':', c='r')
        plotid.plot(lat_austral,clmlmdz6a_seasons[0,:,1], ':', c='orange')
        plotid.plot(lat_austral,clmlmdz6a_seasons[0,:,2], ':', c='b')
        plotid.plot(lat_austral,clmlmdz6a_seasons[0,:,3], ':', c='g')
        plotid.plot(lat_austral, clmlmdz6a_mean, ':', c='k')
        plotid.set_xticks(np.arange(-85,-25,5))
        plotid.set_ylim(0,0.45)
        
    elif pltcounter == 3:
        plotid.set_title("c) High", size=15)
        plotid.set_ylabel('Cloud cover')
        plotid.plot(lat_austral,clhobs_seasons[0,:,0], c='r')
        plotid.plot(lat_austral,clhobs_seasons[0,:,1], c='orange')
        plotid.plot(lat_austral,clhobs_seasons[0,:,2], c='b')
        plotid.plot(lat_austral,clhobs_seasons[0,:,3], c='g')
        plotid.plot(lat_austral, clhobs_mean, c='k')
        plotid.plot(lat_austral,clhlmdz6a_seasons[0,:,0], ':', c='r')
        plotid.plot(lat_austral,clhlmdz6a_seasons[0,:,1], ':', c='orange')
        plotid.plot(lat_austral,clhlmdz6a_seasons[0,:,2], ':', c='b')
        plotid.plot(lat_austral,clhlmdz6a_seasons[0,:,3], ':', c='g')
        plotid.plot(lat_austral, clhlmdz6a_mean, ':', c='k')
        plotid.set_xlabel('Latitude')
        plotid.set_xticks(np.arange(-85,-25,5))
        plotid.set_ylim(0,0.45)
    
    elif pltcounter == 4:
        plotid.set_title("d) Total", size=15)
        plotid.plot(lat_austral,cltobs_seasons[0,:,0], c='r', label='OBS DJF')
        plotid.plot(lat_austral,cltobs_seasons[0,:,1], c='orange', label='OBS MAM')
        plotid.plot(lat_austral,cltobs_seasons[0,:,2], c='b', label='OBS JJA')
        plotid.plot(lat_austral,cltobs_seasons[0,:,3], c='g', label='OBS SON')
        plotid.plot(lat_austral, cltobs_mean, c='k', label='OBS annually')
        plotid.plot(lat_austral,cltlmdz6a_seasons[0,:,0], ':', c='r', label='LMDZ6A DJF')
        plotid.plot(lat_austral,cltlmdz6a_seasons[0,:,1], ':', c='orange', label='LMDZ6A MAM')
        plotid.plot(lat_austral,cltlmdz6a_seasons[0,:,2], ':', c='b', label='LMDZ6A JJA')
        plotid.plot(lat_austral,cltlmdz6a_seasons[0,:,3], ':', c='g', label='LMDZ6A SON')
        plotid.plot(lat_austral, cltlmdz6a_mean, ':', c='k', label='LMDZ6A annually')
        plotid.set_xlabel('Latitude')
        plotid.set_xticks(np.arange(-85,-25,5))
        plotid.set_ylim(0.2,1)
        plotid.legend(loc=(0.5,0.1))

fig.suptitle('Zonally averaged GOCCP and LMDZ6A cloud cover', fontsize=20)
fig.tight_layout()
path_fig = '/home/jcharrel/Documents/stage_M2/figures/CALIPSO_seasonal/'
plt.savefig(path_fig+'cl_seasonal_zonal_obs_lmdz6a_austral_ouest.png',dpi=300)

# %%
# SELECT SEASONS AND MEAN 

# OBS
cllobs_DJF = np.mean(np.mean(cllobs_austral, axis=1)[[0,1,11],:], axis=0)
cllobs_MAM = np.mean(np.mean(cllobs_austral, axis=1)[[2,3,4],:], axis=0)
cllobs_JJA = np.mean(np.mean(cllobs_austral, axis=1)[[5,6,7],:], axis=0)
cllobs_SON = np.mean(np.mean(cllobs_austral, axis=1)[[8,9,10],:], axis=0)
cllobs_seasons = np.ma.dstack((cllobs_DJF, cllobs_MAM, cllobs_JJA, cllobs_SON))
cllobs_mean = np.mean(cllobs_seasons, axis=(0,2))

clmobs_DJF = np.mean(np.mean(clmobs_austral, axis=1)[[0,1,11],:], axis=0)
clmobs_MAM = np.mean(np.mean(clmobs_austral, axis=1)[[2,3,4],:], axis=0)
clmobs_JJA = np.mean(np.mean(clmobs_austral, axis=1)[[5,6,7],:], axis=0)
clmobs_SON = np.mean(np.mean(clmobs_austral, axis=1)[[8,9,10],:], axis=0)
clmobs_seasons = np.ma.dstack((clmobs_DJF, clmobs_MAM, clmobs_JJA, clmobs_SON))
clmobs_mean = np.mean(clmobs_seasons, axis=(0,2))

clhobs_DJF = np.mean(np.mean(clhobs_austral, axis=1)[[0,1,11],:], axis=0)
clhobs_MAM = np.mean(np.mean(clhobs_austral, axis=1)[[2,3,4],:], axis=0)
clhobs_JJA = np.mean(np.mean(clhobs_austral, axis=1)[[5,6,7],:], axis=0)
clhobs_SON = np.mean(np.mean(clhobs_austral, axis=1)[[8,9,10],:], axis=0)
clhobs_seasons = np.ma.dstack((clhobs_DJF, clhobs_MAM, clhobs_JJA, clhobs_SON))
clhobs_mean = np.mean(clhobs_seasons, axis=(0,2))

cltobs_DJF = np.mean(np.mean(cltobs_austral, axis=1)[[0,1,11],:], axis=0)
cltobs_MAM = np.mean(np.mean(cltobs_austral, axis=1)[[2,3,4],:], axis=0)
cltobs_JJA = np.mean(np.mean(cltobs_austral, axis=1)[[5,6,7],:], axis=0)
cltobs_SON = np.mean(np.mean(cltobs_austral, axis=1)[[8,9,10],:], axis=0)
cltobs_seasons = np.ma.dstack((cltobs_DJF, cltobs_MAM, cltobs_JJA, cltobs_SON))
cltobs_mean = np.mean(cltobs_seasons, axis=(0,2))

# LMDZ6A
clllmdz6a_DJF = np.mean(np.mean(clllmdz6a_austral, axis=1)[[0,1,11],:], axis=0)
clllmdz6a_MAM = np.mean(np.mean(clllmdz6a_austral, axis=1)[[2,3,4],:], axis=0)
clllmdz6a_JJA = np.mean(np.mean(clllmdz6a_austral, axis=1)[[5,6,7],:], axis=0)
clllmdz6a_SON = np.mean(np.mean(clllmdz6a_austral, axis=1)[[8,9,10],:], axis=0)
clllmdz6a_seasons = np.dstack((clllmdz6a_DJF, clllmdz6a_MAM, clllmdz6a_JJA, clllmdz6a_SON))
clllmdz6a_mean = np.mean(clllmdz6a_seasons, axis=(0,2))

clmlmdz6a_DJF = np.mean(np.mean(clmlmdz6a_austral, axis=1)[[0,1,11],:], axis=0)
clmlmdz6a_MAM = np.mean(np.mean(clmlmdz6a_austral, axis=1)[[2,3,4],:], axis=0)
clmlmdz6a_JJA = np.mean(np.mean(clmlmdz6a_austral, axis=1)[[5,6,7],:], axis=0)
clmlmdz6a_SON = np.mean(np.mean(clmlmdz6a_austral, axis=1)[[8,9,10],:], axis=0)
clmlmdz6a_seasons = np.dstack((clmlmdz6a_DJF, clmlmdz6a_MAM, clmlmdz6a_JJA, clmlmdz6a_SON))
clmlmdz6a_mean = np.mean(clmlmdz6a_seasons, axis=(0,2))

clhlmdz6a_DJF = np.mean(np.mean(clhlmdz6a_austral, axis=1)[[0,1,11],:], axis=0)
clhlmdz6a_MAM = np.mean(np.mean(clhlmdz6a_austral, axis=1)[[2,3,4],:], axis=0)
clhlmdz6a_JJA = np.mean(np.mean(clhlmdz6a_austral, axis=1)[[5,6,7],:], axis=0)
clhlmdz6a_SON = np.mean(np.mean(clhlmdz6a_austral, axis=1)[[8,9,10],:], axis=0)
clhlmdz6a_seasons = np.dstack((clhlmdz6a_DJF, clhlmdz6a_MAM, clhlmdz6a_JJA, clhlmdz6a_SON))
clhlmdz6a_mean = np.mean(clhlmdz6a_seasons, axis=(0,2))

cltlmdz6a_DJF = np.mean(np.mean(cltlmdz6a_austral, axis=1)[[0,1,11],:], axis=0)
cltlmdz6a_MAM = np.mean(np.mean(cltlmdz6a_austral, axis=1)[[2,3,4],:], axis=0)
cltlmdz6a_JJA = np.mean(np.mean(cltlmdz6a_austral, axis=1)[[5,6,7],:], axis=0)
cltlmdz6a_SON = np.mean(np.mean(cltlmdz6a_austral, axis=1)[[8,9,10],:], axis=0)
cltlmdz6a_seasons = np.dstack((cltlmdz6a_DJF, cltlmdz6a_MAM, cltlmdz6a_JJA, cltlmdz6a_SON))
cltlmdz6a_mean = np.mean(cltlmdz6a_seasons, axis=(0,2))

# %%
fig, axes = plt.subplots(figsize=(16,9), nrows=2, ncols=2)
pltcounter = 0
for plotid in axes.flat:
    pltcounter = pltcounter + 1
    if pltcounter == 1:
        plotid.set_title("a) Low", size=15)
        plotid.set_ylabel('Cloud cover')
        plotid.plot(lon_ouest,cllobs_seasons[0,:,0], c='r')
        plotid.plot(lon_ouest,cllobs_seasons[0,:,1], c='orange')
        plotid.plot(lon_ouest,cllobs_seasons[0,:,2], c='b')
        plotid.plot(lon_ouest,cllobs_seasons[0,:,3], c='g')
        plotid.plot(lon_ouest, cllobs_mean, c='k')
        plotid.plot(lon_ouest,clllmdz6a_seasons[0,:,0], ':', c='r')
        plotid.plot(lon_ouest,clllmdz6a_seasons[0,:,1], ':', c='orange')
        plotid.plot(lon_ouest,clllmdz6a_seasons[0,:,2], ':', c='b')
        plotid.plot(lon_ouest,clllmdz6a_seasons[0,:,3], ':', c='g')
        plotid.plot(lon_ouest, clllmdz6a_mean, ':', c='k')
        plotid.set_xticks(np.arange(-180,10,20))
        
    elif pltcounter == 2:
        plotid.set_title("b) Mid", size=15)
        plotid.plot(lon_ouest,clmobs_seasons[0,:,0], c='r')
        plotid.plot(lon_ouest,clmobs_seasons[0,:,1], c='orange')
        plotid.plot(lon_ouest,clmobs_seasons[0,:,2], c='b')
        plotid.plot(lon_ouest,clmobs_seasons[0,:,3], c='g')
        plotid.plot(lon_ouest, clmobs_mean, c='k')
        plotid.plot(lon_ouest,clmlmdz6a_seasons[0,:,0], ':', c='r')
        plotid.plot(lon_ouest,clmlmdz6a_seasons[0,:,1], ':', c='orange')
        plotid.plot(lon_ouest,clmlmdz6a_seasons[0,:,2], ':', c='b')
        plotid.plot(lon_ouest,clmlmdz6a_seasons[0,:,3], ':', c='g')
        plotid.plot(lon_ouest, clmlmdz6a_mean, ':', c='k')
        plotid.set_xticks(np.arange(-180,10,20))
        
    elif pltcounter == 3:
        plotid.set_title("c) High", size=15)
        plotid.set_ylabel('Cloud cover')
        plotid.plot(lon_ouest,clhobs_seasons[0,:,0], c='r')
        plotid.plot(lon_ouest,clhobs_seasons[0,:,1], c='orange')
        plotid.plot(lon_ouest,clhobs_seasons[0,:,2], c='b')
        plotid.plot(lon_ouest,clhobs_seasons[0,:,3], c='g')
        plotid.plot(lon_ouest, clhobs_mean, c='k')
        plotid.plot(lon_ouest,clhlmdz6a_seasons[0,:,0], ':', c='r')
        plotid.plot(lon_ouest,clhlmdz6a_seasons[0,:,1], ':', c='orange')
        plotid.plot(lon_ouest,clhlmdz6a_seasons[0,:,2], ':', c='b')
        plotid.plot(lon_ouest,clhlmdz6a_seasons[0,:,3], ':', c='g')
        plotid.plot(lon_ouest, clhlmdz6a_mean, ':', c='k')
        plotid.set_xlabel('Longitude')
        plotid.set_xticks(np.arange(-180,10,20))
        
    elif pltcounter == 4:
        plotid.set_title("d) Total", size=15)
        plotid.plot(lon_ouest,cltobs_seasons[0,:,0], c='r', label='OBS DJF')
        plotid.plot(lon_ouest,cltobs_seasons[0,:,1], c='orange', label='OBS MAM')
        plotid.plot(lon_ouest,cltobs_seasons[0,:,2], c='b', label='OBS JJA')
        plotid.plot(lon_ouest,cltobs_seasons[0,:,3], c='g', label='OBS SON')
        plotid.plot(lon_ouest, cltobs_mean, c='k', label='OBS annually')
        plotid.plot(lon_ouest,cltlmdz6a_seasons[0,:,0], ':', c='r')
        plotid.plot(lon_ouest,cltlmdz6a_seasons[0,:,1], ':', c='orange')
        plotid.plot(lon_ouest,cltlmdz6a_seasons[0,:,2], ':', c='b')
        plotid.plot(lon_ouest,cltlmdz6a_seasons[0,:,3], ':', c='g')
        plotid.plot(lon_ouest, cltlmdz6a_mean, ':', c='k')
        plotid.set_xlabel('Longitude')
        plotid.set_xticks(np.arange(-180,10,20))
        plotid.legend(loc=(0.05,0.05))

fig.suptitle('Meridionally averaged ({}°S - {}°S) GOCCP and LMDZ6A cloud cover'.format(-np.max(lat_austral), -np.min(lat_austral)), fontsize=20)
fig.tight_layout()
path_fig = '/home/jcharrel/Documents/stage_M2/figures/CALIPSO_seasonal/'
plt.savefig(path_fig+'cl_seasonal_meridional_obs_lmdz6a_austral_ouest.png',dpi=300)
